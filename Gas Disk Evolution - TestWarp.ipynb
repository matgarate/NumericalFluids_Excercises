# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import iv
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
def InitialCondition_Delta(r,r0,Sigma0):
    dr=r[1]-r[0]
    Sigma=np.zeros(r.size)
    delta= np.where(np.fabs(r-r0)<=dr)[0]
    
    Sigma[delta]=Sigma0* (1.0 - np.fabs(r-r0)[delta]/dr) 
    return Sigma

def InitialCondition_PowerLaw(r,r0,Sigma0,exp):
    
    return Sigma0*np.power(r/r0,exp)

def LyndenBellPringle(r,t,r0,Sigma0,visc0,gamma):
    x = r/r0
    ts=r0*r0/(visc0*3.0*(2.0-gamma)**2)
    tau=1.0+ t/ts
    T= tau**(-(2.5-gamma)/(2.0-gamma))
    
    Cte=np.exp(1)*Sigma0
    return Cte*T*np.power(x,-gamma)*np.exp(-np.power(x,2.0-gamma)/tau)


def GreenSolution(r,t,r0,m,visc):
    x=r/r0
    tau= t*12.0*visc/(r0*r0)
    
    return m/(np.pi*r0**2*tau)*x**(-0.25)*np.exp(-(1+x*x)/tau)*iv(0.25,2.*x/tau)

# %%
def BoundaryCondition_InnerCopy(r,Sigma):
    Sigma[0]=Sigma[1]
    
def BoundaryCondition_OuterCopy(r,Sigma):
    Sigma[nr-1]=Sigma[nr-2]
    

def BoundaryCondition_Inner(r,Sigma,boundary):
    Sigma[0]=boundary
    
def BoundaryCondition_Outer(r,Sigma,boundary):
    Sigma[-1]=boundary

# %%
def CFL_Condition_Diff(dr,Diffusion):
    Diffusion_Max=np.amax(Diffusion)
    
    if Diffusion_Max>0:
        Courant_Diff= 0.3*dr*dr/Diffusion_Max
        return Courant_Diff
    else:
        return np.infty
    
def CFL_Condition_Vel(dr,u):
    v_max=np.amax(u)
    if v_max>0:
        Courant_Vel= np.divide(0.1*dr,v_max)
        return np.amin(Courant_Vel)
    else:
        return np.infty

# %%
def Compute_Diffusion(r,Sigma,visc):
    #Following equation 5.8 in the diffusion form
    '''
    #This does NOT work!
    dr=r[1]-r[0]
    Diff=3.0*visc    
    dq=np.zeros_like(q)    
    dq[1:nr-1]= Diff*(q[2:nr] - 2.0*q[1:nr-1] + q[0:nr-2])/(dr*dr)
    '''
    
    #This Works
    s=2.0*np.sqrt(r)
    q=np.multiply(Sigma*visc,s)
    
    dq_dr2=np.zeros_like(q)
    dq_dr2[1:nr-1]= np.divide(q[2:nr]-q[1:nr-1],s[2:nr]-s[1:nr-1]) - np.divide(q[1:nr-1]-q[0:nr-2],s[1:nr-1]-s[0:nr-2])
    dq_dr2[1:nr-1]= 2.0*np.divide(dq_dr2[1:nr-1],s[2:nr]-s[0:nr-2])
    
    dSigma_dt=12.0*np.divide(dq_dr2,np.power(s,3.0))
    
    return dSigma_dt

# %%
def Compute_Velocity(r,Sigma,visc):
    nr=r.size
    dr=r[1]-r[0]
    
    Sigr= np.multiply(Sigma,np.sqrt(r))
    Arg=np.multiply(Sigr,visc)
    
    r_05=0.5*(r[0:nr-1]+r[1:nr])
    Sigr_05= 0.5*(Sigr[0:nr-1]+Sigr[1:nr])
    
    d_Arg_05= (Arg[1:nr]-Arg[0:nr-1])/(r[1:nr]-r[0:nr-1])

    u_05 = -3.0*np.divide(d_Arg_05,Sigr_05)
    u_inter=interp1d(r_05,u_05,kind="linear",fill_value="extrapolate")
    
    return u_inter(r)

# %%
def DonnorCell_Advection(r,q,u):
    nr=r.size
    dr=r[1]-r[0]
    
    u_05= 0.5*(u[0:nr-1]+u[1:nr]) #Velocity at the Interfaces
    flux_05= np.zeros(nr-1)  #Flux at the interfaces
    r_05= 0.5*(r[0:nr-1]+r[1:nr])
    
    positive=np.where(u_05>0)[0]  #Interfaces where the flux comes from the left
    negative=np.where(u_05<0)[0]  #Interfaces where the flux comes from the right
        
    flux_05[positive]= np.multiply(q[positive], u_05[positive])
    flux_05[negative]= np.multiply(q[negative+1], u_05[negative])
    
    q_flux=np.zeros(nr)
    q_flux[1:nr-1]= (flux_05[0:nr-2]-flux_05[1:nr-1])/(r_05[1:nr-1]-r_05[0:nr-2])  #Notice that the cell 0 and nr-1 are ignored
    
    return q_flux

# %%
def ViscProfile(r,Sigma,chi,epsilon,visc_active,visc_dead):
    factor= 1.0 - np.tanh(epsilon*(Sigma-chi))
    return visc_dead+ visc_active*factor*0.5

# %%
Mstar=1.0           #Solar Mass
r0=1.0              #AU
m_disk=0.01*Mstar   #Disk mass
visc0=0.2          #Weird Units
gamma=0.0

t_orbit=2.0*np.pi
t_visc=r0*r0/(visc0*3.0*(2.0-gamma)**2)

nr=500
r_min=0.01
r_max=2.0

dr=(r_max-r_min)/nr
r=np.linspace(r_min+0.5*dr,r_max-0.5*dr,num=nr,endpoint=True)

#visc= visc0*np.power(r/r0,gamma)

t_start=0.0*t_visc
total_num=6
t_output=t_visc*np.power(2.0, 2.0*np.arange(1,total_num+1)-1.0)/1000.
dt=0.01*t_visc



Sigma0=m_disk/(2.0*np.pi*r0*dr)
#Sigma=InitialCondition_Delta(r,r0,Sigma0)+0.0001*Sigma0
Sigma=LyndenBellPringle(r,0.0,r0,Sigma0,visc0,gamma)

visc=ViscProfile(r,Sigma,Sigma0,0.2,visc0,0.001*visc0)
u=Compute_Velocity(r,Sigma,visc)

floor_Sigma=np.amin(Sigma)

# %%
t=t_start
t_save=t_output[0]
s=0


Output_Dens=[]
Output_Dens.append(np.copy(Sigma))

while t<t_output[-1]:
    
    #Find the timestep using Courant Condition
    dt_0=np.amin([dt,t_save-t, CFL_Condition_Diff(dr,3.0*visc),CFL_Condition_Vel(dr,u)])
    
    #Evolve the Density through Diffusion
    #dSigma_dt=Compute_Diffusion(r,Sigma,visc)
    dSigma_dt= DonnorCell_Advection(r,Sigma*r,u)/r
    
    Sigma+=dSigma_dt*dt_0
    
    #Apply Boundary Conditions
    #Notice that the cells 0 and nr-1 are treated as ghost cells and never touched except by the boundary conditions
    #BoundaryCondition_BothSides(r,Sigma,0.0)
    BoundaryCondition_InnerCopy(r,Sigma)
    BoundaryCondition_Outer(r,Sigma,floor_Sigma)
    
    #Compute Velocity
    u=Compute_Velocity(r,Sigma,visc)
    visc=ViscProfile(r,Sigma,Sigma0,0.2,visc0,0.01*visc0)
    
    #Check if it is time to save
    t+=dt_0
    if t>=t_save:
        print("Snapshot "+str(s))
        s=s+1
        if s<t_output.size:
            t_save=t_output[s]
        Output_Dens.append(np.copy(Sigma))
    #Update the Time
# Out:
# Snapshot 0
# Snapshot 1
# Snapshot 2
# Snapshot 3
# Snapshot 4
# Snapshot 5

# %%
plt.figure(1)
plt.xlabel("$\mathdefault{r/r_0}$")
plt.ylabel("$\mathdefault{\pi R_0^2\Sigma/m_{disk}}$")
plt.xlim([r_min,r_max])
#plt.ylim([0.0,6.0])

plt.figure(2)
plt.xlabel("$\mathdefault{r/r_0}$")
plt.ylabel("Residuals")
plt.xlim([r_min,r_max])
#plt.ylim([0.010,0.015])

plt.figure(3)
plt.xlabel("$\mathdefault{r/r_0}$")
plt.ylabel("Viscosity")
plt.xlim([r_min,r_max])
#plt.ylim([0.010,0.015])

colors=['r','b','g','y','m','k']

for s in range(1,len(Output_Dens)):
    time=t_output[s-1]    
    #sigma_analytic=GreenSolution(r,time,r0,m_disk,visc)
    sigma_analytic=LyndenBellPringle(r,time,r0,Sigma0,visc0,gamma)
    
    
    plt.figure(1)
    plt.plot(r/r0, np.pi*r0*r0*Output_Dens[s]/m_disk,colors[s-1],label="t="+str(time/t_visc)+" $\mathdefault{t_0}$" )
    plt.legend()

    plt.figure(2)
    plt.plot(r/r0,(Output_Dens[s]-sigma_analytic)/sigma_analytic,colors[s-1],label="t="+str(time/t_visc)+" $\mathdefault{t_0}$" )
    plt.legend()
    
    plt.figure(3)
    visc=ViscProfile(r,Output_Dens[s],Sigma0,0.2,visc0,0.01*visc0)
    plt.plot(r/r0,visc,colors[s-1],label="t="+str(time/t_visc)+" $\mathdefault{t_0}$" )
    plt.legend()
